# %%
#workout

print("#######################################")

workout = ['Back', 'Chest']
back_exercises = ['Pull ups', 'Rows', 'Back Extension']
chest_workout = ['Bench Press', 'Pec Dec', 'Incline Bench Press']


for workout in workout:
    print(workout)
    for exercise in back_exercises:
        print(exercise)
        for set in range(1, 4):
            print(f"Set{set}")
            for rep in range(1,11):
                print(f"Rep{rep}")
    print("#########################Back workout done, Chest Workout Starts########################################################")
    for exercise in chest_workout:
        print(exercise)
        for set in range(1,4):
            print(f"Set{set}")
            for rep in range(1,11):
                print(f"Rep{rep}")
# Out:
# #######################################
# Back
# Pull ups
# Set1
# Rep1
# Rep2
# Rep3
# Rep4
# Rep5
# Rep6
# Rep7
# Rep8
# Rep9
# Rep10
# Set2
# Rep1
# Rep2
# Rep3
# Rep4
# Rep5
# Rep6
# Rep7
# Rep8
# Rep9
# Rep10
# Set3
# Rep1
# Rep2
# Rep3
# Rep4
# Rep5
# Rep6
# Rep7
# Rep8
# Rep9
# Rep10
# Rows
# Set1
# Rep1
# Rep2
# Rep3
# Rep4
# Rep5
# Rep6
# Rep7
# Rep8
# Rep9
# Rep10
# Set2
# Rep1
# Rep2
# Rep3
# Rep4
# Rep5
# Rep6
# Rep7
# Rep8
# Rep9
# Rep10
# Set3
# Rep1
# Rep2
# Rep3
# Rep4
# Rep5
# Rep6
# Rep7
# Rep8
# Rep9
# Rep10
# Back Extension
# Set1
# Rep1
# Rep2
# Rep3
# Rep4
# Rep5
# Rep6
# Rep7
# Rep8
# Rep9
# Rep10
# Set2
# Rep1
# Rep2
# Rep3
# Rep4
# Rep5
# Rep6
# Rep7
# Rep8
# Rep9
# Rep10
# Set3
# Rep1
# Rep2
# Rep3
# Rep4
# Rep5
# Rep6
# Rep7
# Rep8
# Rep9
# Rep10
# #########################Back workout done, Chest Workout Starts########################################################
# Bench Press
# Set1
# Rep1
# Rep2
# Rep3
# Rep4
# Rep5
# Rep6
# Rep7
# Rep8
# Rep9
# ...
