# %% [markdown]
# Boolean - Only 2 values - True and False

# %% [markdown]
# #Operators
#
# Assignment Operators - assign value to a variable
#
# # Arithmetic Operators
#
# Addition(+): a + b
# Subtraction(-): a - b
# Multiplication(*): a * b
# Division(/): a / b
# Modulus(%): a % b
# Floor division(//): a // b
# Exponentiation(**): a ** b
#
# # Comparison Operators
#
#
# print(3 > 2)     # True, because 3 is greater than 2
# print(3 >= 2)    # True, because 3 is greater than 2
# print(3 < 2)     # False,  because 3 is greater than 2
# print(2 < 3)     # True, because 2 is less than 3
# print(2 <= 3)    # True, because 2 is less than 3
# print(3 == 2)    # False, because 3 is not equal to 2
# print(3 != 2)    # True, because 3 is not equal to 2
# print(len('mango') == len('avocado'))  # False
# print(len('mango') != len('avocado'))  # True
# print(len('mango') < len('avocado'))   # True
# print(len('milk') != len('meat'))      # False
# print(len('milk') == len('meat'))      # True
# print(len('tomato') == len('potato'))  # True
# print(len('python') > len('dragon'))   # False
#
#
# # Comparing something gives either a True or False
#
# print('True == True: ', True == True)
# print('True == False: ', True == False)
# print('False == False:', False == False)

# %% [markdown]
# In addition to the above comparison operator Python uses:
#
# is: Returns true if both variables are the same object(x is y)
# is not: Returns true if both variables are not the same object(x is not y)
# in: Returns True if the queried list contains a certain item(x in y)
# not in: Returns True if the queried list doesn't have a certain item(x not in y)

# %%
print('1 is 1', 1 is 1)                   # True - because the data values are the same
print('1 is not 2', 1 is not 2)           # True - because 1 is not 2
print('A in Asabeneh', 'A' in 'Asabeneh') # True - A found in the string
print('B not in Asabeneh', 'B' in 'Asabeneh') # False - there is no uppercase B
print('coding' in 'coding for all') # True - because coding for all has the word coding
print('a in an:', 'a' in 'an')      # True
print('4 is 2 ** 2:', 4 is 2 ** 2)   # True
# Out:
# 1 is 1 True
# 1 is not 2 True
# A in Asabeneh True
# B not in Asabeneh False
# True
# a in an: True
# 4 is 2 ** 2: True
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:7: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\preet\AppData\Local\Temp\ipykernel_52128\2450253098.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print('1 is 1', 1 is 1)                   # True - because the data values are the same
# C:\Users\preet\AppData\Local\Temp\ipykernel_52128\2450253098.py:2: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   print('1 is not 2', 1 is not 2)           # True - because 1 is not 2
# C:\Users\preet\AppData\Local\Temp\ipykernel_52128\2450253098.py:7: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print('4 is 2 ** 2:', 4 is 2 ** 2)   # True

# %% [markdown]
# python uses keywords and, or and not for logical operators

# %%
print(3 > 2 and 4 > 3) # True - because both statements are true
print(3 > 2 and 4 < 3) # False - because the second statement is false
print(3 < 2 and 4 < 3) # False - because both statements are false
print('True and True: ', True and True)
print(3 > 2 or 4 > 3)  # True - because both statements are true
print(3 > 2 or 4 < 3)  # True - because one of the statements is true
print(3 < 2 or 4 < 3)  # False - because both statements are false
print('True or False:', True or False)
print(not 3 > 2)     # False - because 3 > 2 is true, then not True gives False
print(not True)      # False - Negation, the not operator turns true to false
print(not False)     # True
print(not not True)  # True
print(not not False) # False
# Out:
# True
# False
# False
# True and True:  True
# True
# True
# False
# True or False: True
# False
# False
# True
# True
# False

# %%
age = int(input("What is your age?: "))
print(type(age))

height = float (input("What is your height?: "))
print(type(height))

complex_num = complex(input("Enter a complex number: "))
print(type(complex_num))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
# Calcualte area of a triangle



base = float(input("Enter the base: "))
height = float(input("Enter the height: "))

area = 0.5 * base * height

print(f"The area of the triangle is {round(area,2)}")
# Out:
# The area of the triangle is 8.02

# %%
side_a = float(input("Enter the side a: "))
side_b = float(input("Enter the side b: "))
side_c = float(input("Enter the side c: "))

perimeter = side_a + side_b + side_c

print(f"The perimeter of the triangle is {round(perimeter,2)}")
# Out:
# The perimeter of the triangle is 9.0

# %%
length = float(input("Enter the base: "))
width = float(input("Enter the width: "))

area = length * width
perimeter = 2 * (length + width)

print(f"The area of the rectangle is {round(area,2)} & perimeter is {round(perimeter, 2)}")
# Out:
# The area of the rectangle is 20.0 & perimeter is 18.0

# %%
len('python') != len('dragon')
# Out:
# False

# %%
print('on' in 'python' and 'on' in 'dragon')
# Out:
# True

# %%
print('jargon' in 'not full of jargon')
# Out:
# True

# %%
print('on' not in 'jargon' and 'on' not in 'dragon')
# Out:
# False

# %%
print(type(str(float(len('python')))))
# Out:
# <class 'str'>

# %%
print(2//2)
# Out:
# 1

# %%
num_div_by_2 = float(input("Enter a number: "))

if num_div_by_2 % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
print( 7 // 3 == 2.7)
# Out:
# False

# %%
type('10') == type(10)
# Out:
# False

# %%
print(int(9.8) == 10)
# Out:
# False

# %%
hours = float(input("Enter the number of hours you will work in a week: "))
rate_per_hour = float(input("Enter the expected rate per hour: "))



print(f"Your weekly earning is {(hours) * (rate_per_hour)}")
# Out:
# Your weekly earning is 12000.0

# %%
# Ask the user for the number of years
years_lived = int(input("Enter number of years you have lived: "))

# Calculate the number of seconds in one year
# 365 days * 24 hours * 60 minutes * 60 seconds
seconds_in_a_year = 365 * 24 * 60 * 60

# Calculate the total seconds lived
total_seconds = years_lived * seconds_in_a_year

print(f"You have lived for {total_seconds} seconds.")
# Out:
# You have lived for 1324512000 seconds.

# %%
for i in range(1, 6):
    # i is the row number
    # 1 is always 1
    # i is the row number again
    # i ** 2 is the number squared
    # i ** 3 is the number cubed
    print(i, 1, i, i**2, i**3)
# Out:
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125
