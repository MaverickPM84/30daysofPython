# %% [markdown]
# indexing = accessing elements if a sequence using [] (indexing oeprator)
# [start : end : step]

# %%
credit_card_number = "1234-4567-9876-3456"

# print(credit_card_number[0])

#print(credit_card_number[2:6])

print(credit_card_number[-4 : ]) # get last 4 numbers
# Out:
# 3456

# %%
# step

print(credit_card_number[::3])
# Out:
# 145-736

# %%
credit_card_number = credit_card_number[::-1]
print(credit_card_number)
# Out:
# 6543-6789-7654-4321
