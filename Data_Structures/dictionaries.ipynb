# %% [markdown]
# # Dictionaries
# Let's explore another data structure in Python: dictionaries!
#
# Dictionaries are ordered collections that store and access data using key:value pairs.
#
# Python dictionaries use curly braces { } with comma-separated key:value pairs:
#
# dictionary = {
#   key1: value1,
#   key2: value2,
#   key3: value3
# }

# %%
# With lists and tuples, we access their items by index. But with dictionaries, we access their items by key. 🔑

laptop = {
    'brand': 'Apple',
    'model': 'Macbook Pro',
    'size': 14,
    'year': 2023
}

print(laptop)
# Out:
# {'brand': 'Apple', 'model': 'Macbook Pro', 'size': 14, 'year': 2023}

# %% [markdown]
# Each key in a dictionary must be unique and associated with a specific value. This pairing allows for efficient retrieval of data.
# Keys must also be immutable, such as a string.

# %%
# To access the value associated with a specific key in a dictionary, we use [ ] brackets with the key inside.

print(laptop['model'])
# Output: Macbook Pro
# Out:
# Macbook Pro

# %% [markdown]
# Consider a scenario where we are managing a database of artifacts or people, each with unique information.
#
# Let's define a dictionary!

# %%
#Creating a dictionary
student_info = {
    'name': 'Alice',
    'age': 9,
    'grade': 'A'
}

# Accessing dict elements

print('Name:', student_info['name'])
print('Age:', student_info['age'])
print('grade:', student_info['grade'])

#Modifying dict elements

student_info['age'] = 10
print('Updated Age: ', student_info['age'])
# Out:
# Name: Alice
# Age: 9
# grade: A
# Updated Age:  10

# %% [markdown]
# # Dictionary Methods
# Dictionaries come equipped with various methods to streamline common tasks.
# This includes .keys(), .values(), and .items():

# %%
print('Keys:', student_info.keys())

print("Values: ", student_info.values())

print('Items: ', student_info.items())
# Out:
# Keys: dict_keys(['name', 'age', 'grade'])
# Values:  dict_values(['Alice', 10, 'A'])
# Items:  dict_items([('name', 'Alice'), ('age', 10), ('grade', 'A')])

# %% [markdown]
# As one of the cultural capitals of the world, NYC is the home of the Met Museum. 🏛️
#
# It has one of the biggest art collections in the world!
#
# Let’s catalog an artifact from the museum! 🖼️ 👩‍🎨
#
# First, search the Met Museum site for your favorite artifact. Scroll to "Artwork Details" and let's start cataloging.
#
# On the Python editor, create a dictionary with the information of your artifact, including:
#
# artist
# period
# date
# Lastly, print the dictionary. What do you see? What if we just want to print the keys, or the values?

# %%
favorite_artifact = {
    'name': 'Madame Roulin and Her Baby',
    'artist': 'Vincent van Gogh',
    'date': 1888,
    'period': '19th Century'
}

print(favorite_artifact)

print('Keys: ', favorite_artifact.keys())

print('Values:', favorite_artifact.values())
# Out:
# {'name': 'Madame Roulin and Her Baby', 'artist': 'Vincent van Gogh', 'date': 1888, 'period': '19th Century'}
# Keys:  dict_keys(['name', 'artist', 'date', 'period'])
# Values: dict_values(['Madame Roulin and Her Baby', 'Vincent van Gogh', 1888, '19th Century'])
