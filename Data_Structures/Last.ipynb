# %% [markdown]
# Nice job on finishing the first chapter! 🚀
#
# In this chapter, we learned the following:
#
# Tuples are ordered, immutable sequences.
# Dictionaries are ordered sequences of key:value pairs.
# Sets are unordered lists of unique items.
# For a refresher, here are what these data structures look like:

# %%
# Tuple
teams = ('TeamA', 'TeamB')

# Dictionary
basketball_player = {'name': 'LeBron James', 'team': 'Los Angeles Lakers'}

# Set
soccer_positions = {'Forward', 'Midfielder', 'Defender', 'Goalkeeper'}

# %% [markdown]
# Let's put all these data structures together one more time!
#
# Instructions
# Imagine you have a dataset with information about your favorite sports team. 🏀🎾⚽ The goal is to use Python's data structures to organize and analyze this data.
#
# If you can't think of any, feel free to use the Super Bowl 2024 champions, the Kansas City Chiefs. 🏈
#
# As a data analyst for the Kansas City Chiefs you have been given a dataset containing information about the players, their positions, and some game statistics.
#
# Let's start analyzing!
#
# Create a list of dictionaries where each dictionary represents a player. Include attributes such as 'name,' 'position,' and 'jersey number.'
# Print out a list of all player positions in the dataset.
# Choose a player and update their game statistics in the dataset.
# Calculate the average statistics (e.g., yards gained, touchdowns) for all players and print the results.

# %%
# List of dictionaries representing players
players = [
    {
        "name": "Patrick Mahomes",
        "position": "Quarterback",
        "jersey_number": 15,
        "yards_gained": 4183,
        "touchdowns": 27
    },
    {
        "name": "Travis Kelce",
        "position": "Tight End",
        "jersey_number": 87,
        "yards_gained": 984,
        "touchdowns": 5
    },
    {
        "name": "Isiah Pacheco",
        "position": "Running Back",
        "jersey_number": 10,
        "yards_gained": 935,
        "touchdowns": 7
    },
    {
        "name": "Rashee Rice",
        "position": "Wide Receiver",
        "jersey_number": 4,
        "yards_gained": 938,
        "touchdowns": 7
    }
]

# 1. Print all player positions
positions = [player["position"] for player in players]
print("Player Positions:")
print(positions)

# 2. Update a player's statistics
# Suppose Patrick Mahomes gained 100 more yards and 1 more touchdown
for player in players:
    if player["name"] == "Patrick Mahomes":
        player["yards_gained"] += 100
        player["touchdowns"] += 1
        break

print("\nUpdated Patrick Mahomes Stats:")
for player in players:
    if player["name"] == "Patrick Mahomes":
        print(player)

# 3. Calculate average statistics
total_yards = sum(player["yards_gained"] for player in players)
total_touchdowns = sum(player["touchdowns"] for player in players)

average_yards = total_yards / len(players)
average_touchdowns = total_touchdowns / len(players)

print("\nAverage Statistics:")
print(f"Average Yards Gained: {average_yards:.2f}")
print(f"Average Touchdowns: {average_touchdowns:.2f}")
# Out:
# Player Positions:
# ['Quarterback', 'Tight End', 'Running Back', 'Wide Receiver']
#
# Updated Patrick Mahomes Stats:
# {'name': 'Patrick Mahomes', 'position': 'Quarterback', 'jersey_number': 15, 'yards_gained': 4283, 'touchdowns': 28}
#
# Average Statistics:
# Average Yards Gained: 1785.00
# Average Touchdowns: 11.75
